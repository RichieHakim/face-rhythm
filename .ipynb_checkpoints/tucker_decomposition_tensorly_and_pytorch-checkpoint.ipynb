# %%
import sys

sys.path.insert(0, '/media/rich/Home_Linux_partition1/github_repos/tensorly')

import numpy as np

# Import PyTorch
import torch
from torch.autograd import Variable

# # Import TensorLy
# import tensorly as tl
# from tensorly.tucker_tensor import tucker_to_tensor
# from tensorly.random import check_random_state

# %%
sys.path.insert(0, '/media/rich/Home_Linux_partition1/github_repos/tensorly')

import tensorly as tl
import tensorly.decomposition
import tensorly.random

# %%
import platform; print(platform.platform())
import sys; print("Python", sys.version)
import numpy; print("NumPy", numpy.__version__)
import scipy; print("SciPy", scipy.__version__)
import tensorly; print("TensorLy", tensorly.__version__)
import torch; print("PyTorch", torch.__version__)
# Out:
# Linux-5.4.0-54-generic-x86_64-with-glibc2.10
# Python 3.8.5 (default, Sep  4 2020, 07:30:14)
# [GCC 7.3.0]
# NumPy 1.19.2
# SciPy 1.5.2
# TensorLy 0.5.0
# PyTorch 1.7.0

# %%
tl.set_backend('pytorch')

# %% [markdown]
# Make the results reproducible by fixing the random seed

# %%
random_state = 1234
rng = tensorly.random.check_random_state(random_state)
device = 'cuda:0'
# device = 'cpu'

# %% [markdown]
# Define a random tensor which we will try to decompose. We wrap our tensors in Variables so we can backpropagate through them:

# %%
shape = [500, 50, 500, 2]
tensor = tl.tensor(rng.random_sample(shape), device=device, requires_grad=True)

# %% [markdown]
# Initialise a random Tucker decomposition of that tensor

# %%
### import data

dir_inputTensor = f'/media/rich/bigSSD RH/res2p/Camera data/round 4 experiments/mouse 6.28/20201102/cam3/run3'
fileName_inputTensor = f'Sxx_allPixels.npy'
path_inputTensor = f'{dir_inputTensor}/{fileName_inputTensor}'
inputTensor = np.load(path_inputTensor)

# %%
tensor = tl.tensor(inputTensor[:,:,:18000, :] , device=device , requires_grad=True)
# tensor = tl.tensor(tensor[ , device=device , requires_grad=True)

# %%
import gc

del inputTensor
gc.collect()
# Out:
# 51

# %%
rank_toUse = 6
ranks = [rank_toUse , rank_toUse, rank_toUse , rank_toUse]
# core = tl.tensor(rng.random_sample(ranks), device=device, requires_grad=True)
factors = [tl.tensor(rng.random_sample((tensor.shape[i], ranks[i])),
                 device=device, requires_grad=True) for i in range(tl.ndim(tensor))]

weights = tl.tensor(np.ones(rank_toUse) , device=device, requires_grad=True)

# %%
# Now we just iterate through the training loop and backpropagate...

import time

n_iter = 1000
lr = 0.05
penalty = 0.1

optimizer = torch.optim.Adam(factors, lr=lr)

tic = time.time()
for i in range(1, n_iter):
    print(f'hi {i}')
    # Important: do not forget to reset the gradients
    optimizer.zero_grad()

    # Reconstruct the tensor from the decomposed form
#     rec = tucker_to_tensor((core, factors))
    rec = tl.cp_tensor.cp_to_tensor((weights, factors))

    # squared l2 loss
#     loss = (tl.norm(rec - tensor, 2)).cpu().detach()
    loss = tl.norm(rec - tensor, 2)

    # squared l2 penalty on the factors of the decomposition
    for f in factors:
        loss = loss + penalty * f.pow(2).sum()

    loss.backward()
    optimizer.step()

    if i % 1 == 0:
        toc = time.time()
        print(round(toc-tic,2))
        rec_error = tl.norm(rec.data - tensor.data, 2)/tl.norm(tensor.data, 2)
        print("Epoch {},. Rec. error: {}".format(i, rec_error))
        tic = time.time()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-98-7b626a30f391> in <module>
#      26         loss = loss + penalty * f.pow(2).sum()
#      27
# ---> 28     loss.backward()
#      29     optimizer.step()
#      30
#
# ~/miniconda3/envs/torch_env/lib/python3.8/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     219                 retain_graph=retain_graph,
#     220                 create_graph=create_graph)
# --> 221         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     222
#     223     def register_hook(self, hook):
#
# ~/miniconda3/envs/torch_env/lib/python3.8/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#     128         retain_graph = create_graph
#     129
# --> 130     Variable._execution_engine.run_backward(
#     131         tensors, grad_tensors_, retain_graph, create_graph,
#     132         allow_unreachable=True)  # allow_unreachable flag
#
# RuntimeError: CUDA out of memory. Tried to allocate 5.39 GiB (GPU 0; 23.69 GiB total capacity; 21.61 GiB already allocated; 559.81 MiB free; 21.62 GiB reserved in total by PyTorch)

# %%
loss = tl.norm((tl.cp_tensor.cp_to_tensor((weights, factors))) - tensor, 2)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-49-882a130099a8> in <module>
# ----> 1 loss = tl.norm((tl.cp_tensor.cp_to_tensor((weights, factors))).detach() - tensor.detach(), 2)
#
# /media/rich/Home_Linux_partition1/github_repos/tensorly/tensorly/cp_tensor.py in cp_to_tensor(cp_tensor, mask)
#     338
#     339     if mask is None:
# --> 340         full_tensor = T.dot(factors[0]*weights,
#     341                              T.transpose(khatri_rao(factors, skip_matrix=0)))
#     342     else:
#
# /media/rich/Home_Linux_partition1/github_repos/tensorly/tensorly/backend/__init__.py in inner(*args, **kwargs)
#     159
#     160     def inner(*args, **kwargs):
# --> 161         return _get_backend_method(name)(*args, **kwargs)
#     162
#     163     # We don't use `functools.wraps` here because some of the dispatched
#
# RuntimeError: CUDA out of memory. Tried to allocate 7.48 GiB (GPU 0; 23.69 GiB total capacity; 15.22 GiB already allocated; 6.93 GiB free; 15.23 GiB reserved in total by PyTorch)

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook

plt.figure()
plt.plot(factors[1].cpu().detach().numpy())
plt.figure()
plt.plot(factors[2].cpu().detach().numpy())
plt.figure()
plt.plot(factors[3].cpu().detach().numpy())
# Out:
# <img src="data:image/png;base64,..." width="639.2666666666667">
# <img src="data:image/png;base64,..." width="639.2666666666667">
# <img src="data:image/png;base64,..." width="639.2666666666667">
# [<matplotlib.lines.Line2D at 0x7fc714a78ee0>,
#  <matplotlib.lines.Line2D at 0x7fc714a78fd0>,
#  <matplotlib.lines.Line2D at 0x7fc714a840d0>,
#  <matplotlib.lines.Line2D at 0x7fc714a84190>,
#  <matplotlib.lines.Line2D at 0x7fc714a84250>,
#  <matplotlib.lines.Line2D at 0x7fc714a84310>]

# %%
del tensor
# del core
del factors
del rec

# %%
del rec_error
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-92-7a465371be93> in <module>
# ----> 1 del rec_error
#
# NameError: name 'rec_error' is not defined

# %%
del optimizer
del loss

# %%
import gc
gc.collect()
# Out:
# 108

# %%
torch.cuda.empty_cache()
