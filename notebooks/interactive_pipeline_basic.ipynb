# %% [markdown]
# ***
# <center><h1>Face Rhythm</h1></center>
#
# ***
#
# <table><tr>
# <td> <img src="https://images.squarespace-cdn.com/content/5688a31305f8e23aa2893502/1614723283221-5Z5038AT7Y6KCOM2PIU4/Screenshot+from+2021-03-02+17-05-12.png?content-type=image%2Fpng" style="height: 200px"> </td>
# <td> <img src="https://images.squarespace-cdn.com/content/5688a31305f8e23aa2893502/1614723856628-J89PYYSF7K7JATE2KMF9/Screenshot+from+2021-03-02+17-23-46.png?format=300w&content-type=image%2Fpng" style="height: 200px"> </td>
# <td> <img src="https://images.squarespace-cdn.com/content/5688a31305f8e23aa2893502/1614723931026-OORV0RAPZNWV3R8TBOXB/Screenshot+from+2021-03-02+17-25-11.png?format=300w&content-type=image%2Fpng" style="height: 200px"> </td>
# <td> <img src="https://images.squarespace-cdn.com/content/5688a31305f8e23aa2893502/1614724055033-O3GBEF1D9MULFZKI2IUJ/Screenshot+from+2021-03-02+17-27-10.png?format=300w&content-type=image%2Fpng" style="height: 200px"> </td>
# <td> <img src="https://images.squarespace-cdn.com/content/5688a31305f8e23aa2893502/1614723378405-WXN74ZTT1KYZUQGDM07X/face_rhythm_banner2.png?format=1000w&content-type=image%2Fpng" style="height: 200px"> </td>
# </tr></table>
#
# ***
#
# ##### Notebook Shortcuts
# - **[Notebook Setup](#Notebook-Setup)**: Prepare all the necessary config files and folders
# - **[Set ROI](#Set-ROI)**: Set the ROI for the analysis
# - **[Run Optic Flow](#Run-Optic-Flow)**: Run the optic flow analysis
# - **[Clean Optic Flow](#Clean-Optic-Flow)**: Optic flow post-processing
# - **[Convolutional Dimensionality Reduction](#Convolutional-Dimensionality-Reduction)**: Convolutional Dimensionality Reduction
# - **[Analysis](#Analysis)**: Decompose and Analyze the optic flow data in many ways
# - **[Comparisons](#Comparisons)**: Compare Face Rhythm to some peer algorithms
#
# ***

# %% [markdown]
# # Tips on running this notebook:
# In theory it would be nice if you could just enter the path of the video(s) and just let it run all the way through. In practice, there are a few hoops to jump through
# - Run the Notebook Setup Block (two blocks below this one). This should pretty much always be done, even if you are loading precomputed file from disk instead of calculating them. This step loads in some useful meta data used throughout.
# - Even if you are restarting at a specific point in your analysis, run your Setup Block then head down to your current analysis step cell

# %% [markdown]
# # Project Directory Organization
# ------------
#
#     Project Directory
#     ├── config.yaml           <- Configuration parameters to run each module in the pipeline. Dictionary.
#     ├── run_info.json         <- Output information from each module. Dictionary.
#     │
#     ├── run_data              <- Output data from each module.
#     │   ├── Dataset_videos.h5 <- Output data from Dataset_videos class. Contains metadata about the videos.
#     │   ├── ROIs.h5           <- Output data from ROIs class. Contains ROI masks.
#     │   ├── PointTracker.h5   <- Output data from PointTracker class. Contains point tracking data.
#     |   ├── VQT_Analyzer.h5   <- Output data from VQT_Analyzer class. Contains spectral decomposition data.
#     │   ├── TCA.h5            <- Output data from TCA class. Contains TCA decomposition data.
#     │
#     └── visualizations        <- Output visualizations.
#         ├── factors_rearranged_[frequency].png  <- Example of a rearranged factor plot.
#         └── point_tracking_demo.avi             <- Example video.

# %% [markdown]
# ***
# <center><h1>Notebook Setup</h1></center>
#
# ***
#
# ### Creates config and locates videos
#
# **Crucially, always run this first cell every time you run this notebook.**
#
# Also, generally make sure to read through the config parameters before running.
#
# The Project path is the path to a folder (existing or not) where we will store our derived files. I recommend creating a project folder and then copying this notebook into that folder.
# The Video path is the path to a folder containing videos.
# The run name will determine the name of the config. You might create multiple configs if you want to re-run the same data with slightly different parameters
#
# Previous face rhythm users might be familiar with the 'sessions' structure. Some users will want to run multiple sessions through Face Rhythm at the same time. If that's you, then read the docs to see what parameters to change:
# https://face-rhythm.readthedocs.io/
#
# If you did everything according to the readme, you should see that the video_path currently points to a folder containing one sample video in the testing folder. Give this a try!

# %%
# ALWAYS RUN THIS CELL
# widen jupyter notebook window
from IPython.display import display, HTML
display(HTML("<style>.container {width:95% !important; }</style>"))

# %load_ext autoreload
# %autoreload 2
import face_rhythm as fr

from pprint import pprint
from pathlib import Path

import cv2

import numpy as np
import torch
import matplotlib.pyplot

fr.util.get_system_versions(verbose=True);
# Out:
# <style>.container {width:95% !important; }</style>
# Operating System: Linux: 5.15.0-71-generic, #78~20.04.1-Ubuntu SMP Wed Apr 19 11:26:48 UTC 2023, x86_64, node: rich-L-CLASS
# Conda Environment: FR
# Python Version: 3.9.13
# GCC Version: 9.4.0
# PyTorch Version: 1.13.1+cu116
# CUDA Version: 11.6, CUDNN Version: 8302, Number of Devices: 1, Devices: ['device 0: Name=NVIDIA GeForce RTX 3090, Memory=25.403129856 GB'],
# Numpy Version: 1.23.2
# OpenCV Version: 4.6.0
# face-rhythm Version: 0.1.0

# %%
directory_project = '/media/rich/bigSSD/analysis_data/face_rhythm/churchland_data/from_20230429_slack/cam1'
directory_videos  = '/media/rich/bigSSD/other lab data/Churchland data/from_20230502'

filename_strMatch = 'cam1.*avi'  ## You can use regular expressions to search and match more complex strings

# %%
path_config, path_run_info, directory_project = fr.project.prepare_project(
    directory_project=directory_project,
    overwrite_config=False,  ## WARNING! CHECK THIS.
    mkdir=True,    
    initialize_visualization=True,    
    verbose=2,
)
figure_saver = fr.util.Figure_Saver(
    path_config=path_config,
    format_save=['png'],
    kwargs_savefig={'bbox_inches': 'tight', 'pad_inches': 0.1, 'transparent': True, 'dpi': 300},
    overwrite=False,
    verbose=2,
)
# Out:
# Initializing cv2.imshow
# FR: Found config.yaml file at /media/rich/bigSSD/analysis_data/face_rhythm/churchland_data/from_20230429_slack/cam1/config.yaml

# %% [markdown]
# # Prepare video data for point tracking

# %%
paths_videos = fr.helpers.find_paths(
    dir_outer=directory_videos,
    reMatch=filename_strMatch,  ## string to use to search for files in directory. Uses regular expressions!
    depth=0,  ## how many folders deep to search
)

pprint(paths_videos, width=1000)
# Out:
# ['/media/rich/bigSSD/other lab data/Churchland data/from_20230502/2709_PuffyPenguin_20230426_161635_cam1_00000000.avi']

# %% [markdown]
# Make a `BufferedVideoReader` object for reading video file data

# %%
videos = fr.helpers.BufferedVideoReader(
#     video_readers=data.videos, 
    paths_videos=paths_videos,
    buffer_size=1000, 
    prefetch=1, 
    posthold=1,
    method_getitem='by_video',
    verbose=1,
)

# %% [markdown]
# Make a `Dataset_videos` object for referencing the raw video data

# %%
data = fr.data_importing.Dataset_videos(
    bufferedVideoReader=videos,
#     paths_videos=paths_videos,
    contiguous=False,
#     frame_rate_clamp=240,
    verbose=2,
);
# Out:
# <class 'face_rhythm.helpers.BufferedVideoReader'> <class 'type'> <class 'type'> True

# %% [markdown]
# Save the `Dataset_videos` object in the 'analysis_files' project folder

# %%
data.save_config(path_config=path_config, overwrite=True, verbose=1)
data.save_run_info(path_config=path_config, overwrite=True, verbose=1)
data.save_run_data(path_config=path_config, overwrite=True, verbose=1)
# Out:
# FR: No existing run_info.json file found in /media/rich/bigSSD/analysis_data/face_rhythm/churchland_data/from_20230429_slack/cam1/run_info.json.
#  Creating new run_info.json at /media/rich/bigSSD/analysis_data/face_rhythm/churchland_data/from_20230429_slack/cam1/run_info.json
# FR WARNING: path_run_data file is expected to be named 'Dataset_videos.h5' if it is part of a project. Please make sure this is correct.

# %% [markdown]
# # Define ROIs

# %% [markdown]
# Either select new ROIs (`select_mode='gui'`) and provide an exampleImage, or import existing ROIs (`path_file=path_to_ROIs.h5_file`).\
# **Typically, you should make 1 or 2 ROIs. The first defining where the face points should be and the second for cropping the frame.**

# %%
exampleImage = data[0][0]
# %matplotlib notebook
rois = fr.rois.ROIs(
    select_mode='gui',
    exampleImage=exampleImage,
#     select_mode='file',
#     path_file=str(Path(directory_project) / 'analysis_files' / 'ROIs.h5'),
    path_file=r'/home/rich/Desktop/ROIs_7.h5',
    verbose=2
)
# Out:
# FR: Initializing GUI...
# <img src="data:image/png;base64,..." width="2076">
# Button(description='Confirm ROI', style=ButtonStyle())
# Button(description='New ROI', style=ButtonStyle())
# mask_frames computed

# %% [markdown]
# Make a point grid out of the first ROI

# %%
rois.make_points(rois=rois[0], point_spacing=10)
# Out:
# FR: Making points to track
# FR: 2362 points total

# %% [markdown]
# Save the `ROIs` object in the 'analysis_files' project folder

# %%
rois.save_config(path_config=path_config, overwrite=True, verbose=1)
rois.save_run_info(path_config=path_config, overwrite=True, verbose=1)
rois.save_run_data(path_config=path_config, overwrite=True, verbose=1)
# Out:
# FR Warning: Overwriting field. 'ROIs' already in config.yaml.
# FR Warning: Overwriting field. 'ROIs' is already a field in the run_info.json dictionary.
# FR WARNING: path_run_data file is expected to be named 'ROIs.h5' if it is part of a project. Please make sure this is correct.
# FR Warning: Overwriting file. File: /media/rich/bigSSD/analysis_data/face_rhythm/churchland_data/from_20230429_slack/cam1/analysis_files/ROIs.h5 already exists.

# %% [markdown]
# visualize the ROIs

# %%
rois.plot_rois(exampleImage)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (<Figure size 640x480 with 1 Axes>, <AxesSubplot:>)

# %% [markdown]
# # Point Tracking

# %% [markdown]
# Prepare `PointTracker` object.\
# Set `visualize_video` to **`True`** to tune parameters until they look appropriate, then set to **`False`** to run the full dataset through at a much faster speed.
#
# Key parameters:
# - `point_spacing`: distance between points. Vary so that total number of points is appropriate.
# - `mesh_rigidity`: how rigid the mesh elasticity is. Vary so that points track well without drift.
# - `relaxation`: how quickly the points relax back to their home position. Vary so that points track well without dift.
# - `kwargs_method > winSize`: the spatial size of the optical flow calculation. Smaller is better but noisier, larger is less accurate but more robust to noise.
# - `params_outlier_handling > threshold_displacement`: point displacements above this value will result in freezing of the points.

# %%
pt = fr.point_tracking.PointTracker(
#     buffered_video_reader=videos[:5],
    buffered_video_reader=videos,
    point_positions=rois.point_positions,
    rois_masks=[rois[1]],
    contiguous=False,
    params_optical_flow={
        "method": "lucas_kanade",
        "mesh_rigidity": 0.2,
        "mesh_n_neighbors": 30,
        "relaxation": 0.0030,
        "kwargs_method": {
            "winSize": [30,30],
            "maxLevel": 2,
            "criteria": [cv2.TERM_CRITERIA_EPS | cv2.TERM_CRITERIA_COUNT, 2, 0.03],
        },        
    },
    visualize_video=False,
    params_visualization={
                'alpha':0.5,
                'point_sizes':2,
    },
    params_outlier_handling = {
        'threshold_displacement': 150,  ## Maximum displacement between frames, in pixels.
        'framesHalted_before': 3,  ## Number of frames to halt tracking before a violation.
        'framesHalted_after': 3,  ## Number of frames to halt tracking after a violation.
    },

    verbose=2,
)
# Out:
# FR: 2362 points will be tracked
# FR: Collapsing mask ROI images into single mask
# FR: Initializing mesh distances

# %% [markdown]
# Perform point tracking

# %%
pt.track_points()

# %% [markdown]
# Save the `PointTracker` object in 'analysis_files' project directory.\
# Using compression can reduce file sizes slightly but is very slow.

# %%
pt.save_config(path_config=path_config, overwrite=True, verbose=1)
pt.save_run_info(path_config=path_config, overwrite=True, verbose=2)
pt.save_run_data(path_config=path_config, overwrite=True, use_compression=False, verbose=1)
# Out:
# FR: Loading file /media/rich/bigSSD/analysis_data/face_rhythm/churchland_data/from_20230429_slack/cam1/run_info.json
# FR: Adding 'PointTracker' field to run_info.json
# FR: Saving run_info.json to /media/rich/bigSSD/analysis_data/face_rhythm/churchland_data/from_20230429_slack/cam1/run_info.json
# FR WARNING: path_run_data file is expected to be named 'PointTracker.h5' if it is part of a project. Please make sure this is correct.

# %% [markdown]
# Clear some memory if needed. Optional.

# %%
pt.cleanup()
# Out:
# FR: Deleting all attributes

# %% [markdown]
# Load the `PointTracker` data as a dictionary

# %%
pt_data = fr.h5_handling.simple_load(str(Path(directory_project) / 'analysis_files' / 'PointTracker.h5'))

# %% [markdown]
# # Spectral Analysis

# %% [markdown]
# Prepare `VQT_Analyzer` object.
#
# Key parameters:
# - `Q_lowF`:  Quality of the lowest frequency band of the spectrogram. Q value is number of oscillation periods.
# - `Q_highF`: Quality of the highest frequency band...
# - `F_min`: Lowest frequency band to use.
# - `F_max`: Highest frequency band to use.
# - `downsample_factor`: How much to downsample the spectrogram by in time.
# - `return_complex`: Whether or not to return the complex spectrogram. Generally set to False unless you want to try something fancy.

# %%
Fs = fr.util.load_run_info_file(path_run_info)['Dataset_videos']['frame_rate']

spec = fr.spectral_analysis.VQT_Analyzer(
    params_VQT = {
        'Fs_sample': Fs, 
        'Q_lowF': 2, 
        'Q_highF': 8, 
        'F_min': 1, 
        'F_max': int(data.frame_rate/2), 
        'n_freq_bins': 40, 
        'win_size': 701, 
        'plot_pref': True, 
        'downsample_factor': 20, 
        'padding': 'valid',
        'DEVICE_compute': 'cpu', 
        'batch_size': 10,
        'return_complex': False, 
        'progressBar': True
    },
    normalization_factor=0.95,
    spectrogram_exponent=1.0,
    one_over_f_exponent=0.5,
    verbose = 2,
)

# %% [markdown]
# Look at a demo spectrogram of a single point.\
# Specify the point with the `idx_point` and `name_points` fields.\
# Note that the `pt_data['points_tracked']` dictionary holds subdictionaries withe numeric string names (ie `['0'], ['1']`) for each video.

# %%
spec_demo, xAxis_demo, freqs_demo = spec.demo_transform(
    points_tracked=pt_data['points_tracked'],
    point_positions=pt_data['point_positions'],
    idx_point=30,
    name_points='0',
    plot=True,
);
# Out:
# 100%|█████████████████████████████████████████████| 1/1 [00:09<00:00,  9.74s/it]
# Demo spectrogram shape: (2, 40, 8325)
# Total size of all spectrograms: 6.31806656 GB
# Individual spectrogram sizes (in GB): [6.31806656]

# %% [markdown]
# Generate spectrograms

# %%
spec.transform_all(
    points_tracked=pt_data['points_tracked'],
    point_positions=pt_data['point_positions'],
)
# Out:
# Preparing traces. Reshaping and subtracting offsets...
# Computing spectrograms...
# Computing spectrograms:   0%|                             | 0/1 [00:00<?, ?it/s]
#
#   0%|                                                   | 0/473 [00:00<?, ?it/s]
#
#   1%|▎                                          | 4/473 [00:00<00:14, 32.61it/s]
#
#   2%|▋                                          | 8/473 [00:00<00:14, 32.82it/s]
#
#   3%|█                                         | 12/473 [00:00<00:13, 33.25it/s]
#
#   3%|█▍                                        | 16/473 [00:00<00:13, 33.50it/s]
#
#   4%|█▊                                        | 20/473 [00:00<00:13, 33.48it/s]
#
#   5%|██▏                                       | 24/473 [00:00<00:13, 33.63it/s]
#
#   6%|██▍                                       | 28/473 [00:00<00:13, 33.65it/s]
#
#   7%|██▊                                       | 32/473 [00:00<00:13, 33.64it/s]
#
#   8%|███▏                                      | 36/473 [00:01<00:12, 33.65it/s]
#
#   8%|███▌                                      | 40/473 [00:01<00:12, 33.69it/s]
#
#   9%|███▉                                      | 44/473 [00:01<00:12, 33.62it/s]
#
#  10%|████▎                                     | 48/473 [00:01<00:12, 33.78it/s]
#
#  11%|████▌                                     | 52/473 [00:01<00:12, 33.83it/s]
#
#  12%|████▉                                     | 56/473 [00:01<00:12, 33.94it/s]
#
#  13%|█████▎                                    | 60/473 [00:01<00:12, 33.79it/s]
#
#  14%|█████▋                                    | 64/473 [00:01<00:12, 33.99it/s]
#
#  14%|██████                                    | 68/473 [00:02<00:12, 33.61it/s]
#
#  15%|██████▍                                   | 72/473 [00:02<00:12, 33.22it/s]
#
#  16%|██████▋                                   | 76/473 [00:02<00:12, 32.95it/s]
#
#  17%|███████                                   | 80/473 [00:02<00:11, 32.85it/s]
#
#  18%|███████▍                                  | 84/473 [00:02<00:11, 33.11it/s]
#
#  19%|███████▊                                  | 88/473 [00:02<00:11, 33.25it/s]
#
#  19%|████████▏                                 | 92/473 [00:02<00:11, 33.37it/s]
#
#  20%|████████▌                                 | 96/473 [00:02<00:11, 33.52it/s]
#
#  21%|████████▋                                | 100/473 [00:02<00:11, 33.12it/s]
#
#  22%|█████████                                | 104/473 [00:03<00:11, 33.04it/s]
#
#  23%|█████████▎                               | 108/473 [00:03<00:11, 33.12it/s]
#
#  24%|█████████▋                               | 112/473 [00:03<00:10, 33.01it/s]
#
#  25%|██████████                               | 116/473 [00:03<00:10, 33.02it/s]
#
#  25%|██████████▍                              | 120/473 [00:03<00:10, 32.89it/s]
#
#  26%|██████████▋                              | 124/473 [00:03<00:10, 33.04it/s]
#
#  27%|███████████                              | 128/473 [00:03<00:10, 32.85it/s]
#
#  28%|███████████▍                             | 132/473 [00:03<00:10, 32.68it/s]
#
#  29%|███████████▊                             | 136/473 [00:04<00:10, 32.38it/s]
#
#  30%|████████████▏                            | 140/473 [00:04<00:10, 32.68it/s]
#
#  30%|████████████▍                            | 144/473 [00:04<00:10, 32.77it/s]
#
#  31%|████████████▊                            | 148/473 [00:04<00:09, 32.68it/s]
#
#  32%|█████████████▏                           | 152/473 [00:04<00:09, 32.60it/s]
#
#  33%|█████████████▌                           | 156/473 [00:04<00:09, 32.72it/s]
#
#  34%|█████████████▊                           | 160/473 [00:04<00:09, 32.63it/s]
#
#  35%|██████████████▏                          | 164/473 [00:04<00:09, 32.54it/s]
#
#  36%|██████████████▌                          | 168/473 [00:05<00:09, 32.71it/s]
#
#  36%|██████████████▉                          | 172/473 [00:05<00:09, 32.83it/s]
#
#  37%|███████████████▎                         | 176/473 [00:05<00:09, 33.00it/s]
#
#  38%|███████████████▌                         | 180/473 [00:05<00:08, 32.83it/s]
#
#  39%|███████████████▉                         | 184/473 [00:05<00:08, 32.68it/s]
#
#  40%|████████████████▎                        | 188/473 [00:05<00:08, 32.65it/s]
#
#  41%|████████████████▋                        | 192/473 [00:05<00:08, 32.63it/s]
#
#  41%|████████████████▉                        | 196/473 [00:05<00:08, 32.38it/s]
#
#  42%|█████████████████▎                       | 200/473 [00:06<00:08, 32.26it/s]
#
#  43%|█████████████████▋                       | 204/473 [00:06<00:08, 32.23it/s]
#
#  44%|██████████████████                       | 208/473 [00:06<00:08, 32.34it/s]
#
#  45%|██████████████████▍                      | 212/473 [00:06<00:08, 32.39it/s]
#
#  46%|██████████████████▋                      | 216/473 [00:06<00:07, 32.38it/s]
#
#  47%|███████████████████                      | 220/473 [00:06<00:07, 32.42it/s]
#
#  47%|███████████████████▍                     | 224/473 [00:06<00:07, 32.35it/s]
#
#  48%|███████████████████▊                     | 228/473 [00:06<00:07, 32.30it/s]
#
#  49%|████████████████████                     | 232/473 [00:07<00:07, 32.20it/s]
#
#  50%|████████████████████▍                    | 236/473 [00:07<00:07, 32.35it/s]
#
#  51%|████████████████████▊                    | 240/473 [00:07<00:07, 32.29it/s]
#
#  52%|█████████████████████▏                   | 244/473 [00:07<00:07, 32.56it/s]
#
#  52%|█████████████████████▍                   | 248/473 [00:07<00:06, 32.68it/s]
#
#  53%|█████████████████████▊                   | 252/473 [00:07<00:06, 32.81it/s]
#
#  54%|██████████████████████▏                  | 256/473 [00:07<00:06, 32.85it/s]
#
#  55%|██████████████████████▌                  | 260/473 [00:07<00:06, 32.62it/s]
#
#  56%|██████████████████████▉                  | 264/473 [00:08<00:06, 32.23it/s]
#
#  57%|███████████████████████▏                 | 268/473 [00:08<00:06, 32.30it/s]
#
#  58%|███████████████████████▌                 | 272/473 [00:08<00:06, 32.21it/s]
#
#  58%|███████████████████████▉                 | 276/473 [00:08<00:06, 32.53it/s]
#
#  59%|████████████████████████▎                | 280/473 [00:08<00:05, 32.57it/s]
#
#  60%|████████████████████████▌                | 284/473 [00:08<00:05, 32.88it/s]
#
#  61%|████████████████████████▉                | 288/473 [00:08<00:05, 32.64it/s]
#
#  62%|█████████████████████████▎               | 292/473 [00:08<00:05, 32.44it/s]
#
#  63%|█████████████████████████▋               | 296/473 [00:09<00:05, 32.20it/s]
#
#  63%|██████████████████████████               | 300/473 [00:09<00:05, 32.26it/s]
#
#  64%|██████████████████████████▎              | 304/473 [00:09<00:05, 32.23it/s]
#
#  65%|██████████████████████████▋              | 308/473 [00:09<00:05, 32.34it/s]
#
#  66%|███████████████████████████              | 312/473 [00:09<00:04, 32.36it/s]
#
#  67%|███████████████████████████▍             | 316/473 [00:09<00:04, 32.38it/s]
#
#  68%|███████████████████████████▋             | 320/473 [00:09<00:04, 32.17it/s]
#
#  68%|████████████████████████████             | 324/473 [00:09<00:04, 32.26it/s]
#
#  69%|████████████████████████████▍            | 328/473 [00:10<00:04, 32.39it/s]
#
#  70%|████████████████████████████▊            | 332/473 [00:10<00:04, 32.49it/s]
#
#  71%|█████████████████████████████            | 336/473 [00:10<00:04, 32.30it/s]
#
#  72%|█████████████████████████████▍           | 340/473 [00:10<00:04, 32.42it/s]
#
#  73%|█████████████████████████████▊           | 344/473 [00:10<00:03, 32.61it/s]
#
#  74%|██████████████████████████████▏          | 348/473 [00:10<00:03, 32.62it/s]
#
#  74%|██████████████████████████████▌          | 352/473 [00:10<00:03, 32.37it/s]
#
#  75%|██████████████████████████████▊          | 356/473 [00:10<00:03, 32.55it/s]
#
#  76%|███████████████████████████████▏         | 360/473 [00:10<00:03, 32.61it/s]
#
#  77%|███████████████████████████████▌         | 364/473 [00:11<00:03, 32.46it/s]
#  78%|███████████████████████████████▉         | 368/473 [00:11<00:03, 32.68it/s]
#
#  79%|████████████████████████████████▏        | 372/473 [00:11<00:03, 32.58it/s]
#
#  79%|████████████████████████████████▌        | 376/473 [00:11<00:02, 32.53it/s]
#
#  80%|████████████████████████████████▉        | 380/473 [00:11<00:02, 32.47it/s]
#
#  81%|█████████████████████████████████▎       | 384/473 [00:11<00:02, 32.62it/s]
#
#  82%|█████████████████████████████████▋       | 388/473 [00:11<00:02, 32.63it/s]
#
#  83%|█████████████████████████████████▉       | 392/473 [00:11<00:02, 32.70it/s]
#
#  84%|██████████████████████████████████▎      | 396/473 [00:12<00:02, 32.56it/s]
#
#  85%|██████████████████████████████████▋      | 400/473 [00:12<00:02, 32.69it/s]
#
#  85%|███████████████████████████████████      | 404/473 [00:12<00:02, 32.65it/s]
#
#  86%|███████████████████████████████████▎     | 408/473 [00:12<00:01, 32.76it/s]
#
#  87%|███████████████████████████████████▋     | 412/473 [00:12<00:01, 32.70it/s]
#
#  88%|████████████████████████████████████     | 416/473 [00:12<00:01, 32.67it/s]
#
#  89%|████████████████████████████████████▍    | 420/473 [00:12<00:01, 32.70it/s]
#
#  90%|████████████████████████████████████▊    | 424/473 [00:12<00:01, 32.63it/s]
#
#  90%|█████████████████████████████████████    | 428/473 [00:13<00:01, 32.63it/s]
#
#  91%|█████████████████████████████████████▍   | 432/473 [00:13<00:01, 32.66it/s]
#
#  92%|█████████████████████████████████████▊   | 436/473 [00:13<00:01, 32.62it/s]
#
#  93%|██████████████████████████████████████▏  | 440/473 [00:13<00:01, 32.55it/s]
#
#  94%|██████████████████████████████████████▍  | 444/473 [00:13<00:00, 32.45it/s]
#
#  95%|██████████████████████████████████████▊  | 448/473 [00:13<00:00, 32.56it/s]
#
#  96%|███████████████████████████████████████▏ | 452/473 [00:13<00:00, 32.63it/s]
#
#  96%|███████████████████████████████████████▌ | 456/473 [00:13<00:00, 32.49it/s]
#
#  97%|███████████████████████████████████████▊ | 460/473 [00:14<00:00, 32.54it/s]
#
#  98%|████████████████████████████████████████▏| 464/473 [00:14<00:00, 32.64it/s]
#
#  99%|████████████████████████████████████████▌| 468/473 [00:14<00:00, 32.59it/s]
#
# 100%|█████████████████████████████████████████| 473/473 [00:14<00:00, 32.77it/s]

# %% [markdown]
# Save the `VQT_Analyzer` object in 'analysis_files' project directory.\
# Using compression can reduce file sizes slightly but is very slow.

# %%
spec.save_config(path_config=path_config, overwrite=True, verbose=1)
spec.save_run_info(path_config=path_config, overwrite=True, verbose=1)
spec.save_run_data(path_config=path_config, overwrite=True, use_compression=False, verbose=1)
# Out:
# FR Warning: Overwriting field. 'VQT_Analyzer' already in config.yaml.
# FR Warning: Overwriting field. 'VQT_Analyzer' is already a field in the run_info.json dictionary.
# FR WARNING: path_run_data file is expected to be named 'VQT_Analyzer.h5' if it is part of a project. Please make sure this is correct.
# FR Warning: Overwriting file. File: /media/rich/bigSSD/analysis_data/face_rhythm/churchland_data/from_20230429_slack/cam1/analysis_files/VQT_Analyzer.h5 already exists.
# FR Warning: /media/rich/bigSSD/analysis_data/face_rhythm/churchland_data/from_20230429_slack/cam1/analysis_files/VQT_Analyzer.h5 is already open. Closing all open h5py.File objects and trying again.
# /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:262: UserWarning: torch.distributed.reduce_op is deprecated, please use torch.distributed.ReduceOp instead
#   warnings.warn(

# %% [markdown]
# Clear some memory if needed. Optional.

# %%
spec.cleanup()
# Out:
# FR: Deleting all attributes

# %% [markdown]
# Load the `VQT_Analyzer` data as a dictionary

# %%
spec_data = fr.h5_handling.simple_load(str(Path(directory_project) / 'analysis_files' / 'VQT_Analyzer.h5'), return_dict=True)

# %% [markdown]
# # Decomposition

# %% [markdown]
# Prepare `TCA` object, and then rearrange the data with the `.rearrange_data` method.
#
# Key parameters for `.rearrange_data`:
# - `names_dims_array`:  Enter the names of the dimensions of the spectrogram. Typically these are `'xy', 'points', 'frequency', 'time'`.
# - `names_dims_concat_array`: Enter any dimensions you wish to concatenate along other dimensions. Typically we wish to concatenate the `'xy'` dimension along the `'points'` dimension, so we make a list containing that pair as a tuple: `[('xy', 'points')]`.
# - `concat_complexDim`: If your input data are complex valued, then this can concatenate the complex dimension along another dimension.
# - `name_dim_dictElements`: The `data` argument is expected to be a dictionary of dictionaries of arrays, where the inner dicts are trials or videos. This is the name of what those inner dicts are. Typically `'trials'`.

# %%
# spectrograms = spec_data['spectrograms']
spectrograms = {key: np.abs(val) for key,val in list(spec_data['spectrograms'].items())[:80]}

tca = fr.decomposition.TCA(verbose=2)

tca.rearrange_data(
    data=spectrograms,
    names_dims_array = ['xy', 'points', 'frequency', 'time'],
    names_dims_concat_array = [('xy', 'points')],
    concat_complexDim=False,
    name_dim_concat_complexDim='time',
    name_dim_dictElements = 'session',
    method_handling_dictElements = 'separate',
    name_dim_concat_dictElements = 'time',
    idx_windows=None,
    name_dim_array_window='time',
)
# Out:
# Preparing new names for the concatenated array dimensions. From ['xy', 'points', 'frequency', 'time'] to ['(xy points)', 'frequency', 'time'].
# Rearranging the dict elements using method 'separate'.

# %% [markdown]
# Fit TCA model.
#
# There are a few methods that can be used:
# - `'CP_NN_HALS'`: non-negative CP decomposition using the efficient HALS algorithm. This should be used in most cases.
# - `'CP'`: Standard CP decomposition. Use if input data are not non-negative (if you are using complex valued spectrograms or similar).
# - `'Randomized_CP'`: Randomized CP decomposition. Allows for large input tensors. If you are using huge tensors and you are memory constrained or want to run on a small GPU, this is your only option.
#
# If you have and want to use a CUDA compatible GPU:
# - Set `DEVICE` to `'cuda'`
# - GPU memory can be saved by setting `'init'` method to `'random'`. However, fastest convergence and highest accuracy typically come from `'init': 'svd'`.

# %%
tca.fit(
    method='CP_NN_HALS',
#     method='CP',
    params_method={
        'rank': 12, 
        'n_iter_max': 1000, 
        'init': 'random', 
        'svd': 'truncated_svd', 
        'tol': 1e-09, 
#         'nn_modes': [0,1], 
        'verbose': True, 
    },
    DEVICE='cuda:0',
    verbose=2,
)
# Out:
# Using device: cuda:0
# Using method: <class 'tensorly.decomposition._nn_cp.CP_NN_HALS'>
# Running the TCA model with method 'CP_NN_HALS'.
# /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/FR/lib/python3.9/site-packages/tensorly/backend/pytorch_backend.py:31: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(data, dtype=dtype, device=device,
# reconstruction error=0.49220916628837585
# iteration 1, reconstruction error: 0.3605274260044098, decrease = 0.13168174028396606
# iteration 2, reconstruction error: 0.3433551490306854, decrease = 0.017172276973724365
# iteration 3, reconstruction error: 0.3365004360675812, decrease = 0.006854712963104248
# iteration 4, reconstruction error: 0.33252695202827454, decrease = 0.003973484039306641
# iteration 5, reconstruction error: 0.33010974526405334, decrease = 0.0024172067642211914
# iteration 6, reconstruction error: 0.32876327633857727, decrease = 0.0013464689254760742
# iteration 7, reconstruction error: 0.3280031979084015, decrease = 0.0007600784301757812
# iteration 8, reconstruction error: 0.3275004029273987, decrease = 0.0005027949810028076
# iteration 9, reconstruction error: 0.3271030783653259, decrease = 0.0003973245620727539
# iteration 10, reconstruction error: 0.3267296850681305, decrease = 0.00037339329719543457
# iteration 11, reconstruction error: 0.3263455927371979, decrease = 0.0003840923309326172
# iteration 12, reconstruction error: 0.32595354318618774, decrease = 0.00039204955101013184
# iteration 13, reconstruction error: 0.32559096813201904, decrease = 0.00036257505416870117
# iteration 14, reconstruction error: 0.3252796232700348, decrease = 0.00031134486198425293
# iteration 15, reconstruction error: 0.32502278685569763, decrease = 0.0002568364143371582
# iteration 16, reconstruction error: 0.3248136043548584, decrease = 0.0002091825008392334
# iteration 17, reconstruction error: 0.3246404528617859, decrease = 0.00017315149307250977
# iteration 18, reconstruction error: 0.32449308037757874, decrease = 0.00014737248420715332
# iteration 19, reconstruction error: 0.3243649899959564, decrease = 0.00012809038162231445
# iteration 20, reconstruction error: 0.32425054907798767, decrease = 0.00011444091796875
# iteration 21, reconstruction error: 0.32414573431015015, decrease = 0.00010481476783752441
# iteration 22, reconstruction error: 0.32404825091362, decrease = 9.748339653015137e-05
# iteration 23, reconstruction error: 0.3239545524120331, decrease = 9.369850158691406e-05
# iteration 24, reconstruction error: 0.32386481761932373, decrease = 8.973479270935059e-05
# iteration 25, reconstruction error: 0.3237786293029785, decrease = 8.618831634521484e-05
# iteration 26, reconstruction error: 0.3236943185329437, decrease = 8.431077003479004e-05
# iteration 27, reconstruction error: 0.3236123025417328, decrease = 8.20159912109375e-05
# iteration 28, reconstruction error: 0.3235325813293457, decrease = 7.972121238708496e-05
# iteration 29, reconstruction error: 0.3234545588493347, decrease = 7.802248001098633e-05
# iteration 30, reconstruction error: 0.3233790397644043, decrease = 7.551908493041992e-05
# iteration 31, reconstruction error: 0.32330411672592163, decrease = 7.492303848266602e-05
# iteration 32, reconstruction error: 0.32323089241981506, decrease = 7.322430610656738e-05
# iteration 33, reconstruction error: 0.32315847277641296, decrease = 7.241964340209961e-05
# iteration 34, reconstruction error: 0.3230877220630646, decrease = 7.075071334838867e-05
# iteration 35, reconstruction error: 0.3230184316635132, decrease = 6.92903995513916e-05
# iteration 36, reconstruction error: 0.3229508101940155, decrease = 6.762146949768066e-05
# iteration 37, reconstruction error: 0.32288533449172974, decrease = 6.54757022857666e-05
# iteration 38, reconstruction error: 0.32282236218452454, decrease = 6.29723072052002e-05
# iteration 39, reconstruction error: 0.32276126742362976, decrease = 6.109476089477539e-05
# iteration 40, reconstruction error: 0.3227024972438812, decrease = 5.8770179748535156e-05
# iteration 41, reconstruction error: 0.32264623045921326, decrease = 5.626678466796875e-05
# iteration 42, reconstruction error: 0.3225916624069214, decrease = 5.456805229187012e-05
# iteration 43, reconstruction error: 0.32253965735435486, decrease = 5.200505256652832e-05
# iteration 44, reconstruction error: 0.32249075174331665, decrease = 4.890561103820801e-05
# iteration 45, reconstruction error: 0.32244420051574707, decrease = 4.655122756958008e-05
# iteration 46, reconstruction error: 0.32239893078804016, decrease = 4.526972770690918e-05
# iteration 47, reconstruction error: 0.3223555386066437, decrease = 4.3392181396484375e-05
# iteration 48, reconstruction error: 0.32231405377388, decrease = 4.1484832763671875e-05
# iteration 49, reconstruction error: 0.3222734034061432, decrease = 4.0650367736816406e-05
# iteration 50, reconstruction error: 0.3222344219684601, decrease = 3.898143768310547e-05
# iteration 51, reconstruction error: 0.3221960961818695, decrease = 3.832578659057617e-05
# iteration 52, reconstruction error: 0.3221583962440491, decrease = 3.769993782043457e-05
# iteration 53, reconstruction error: 0.322122186422348, decrease = 3.6209821701049805e-05
# iteration 54, reconstruction error: 0.322086364030838, decrease = 3.5822391510009766e-05
# iteration 55, reconstruction error: 0.3220507800579071, decrease = 3.55839729309082e-05
# iteration 56, reconstruction error: 0.3220156133174896, decrease = 3.516674041748047e-05
# iteration 57, reconstruction error: 0.32198086380958557, decrease = 3.4749507904052734e-05
# iteration 58, reconstruction error: 0.32194632291793823, decrease = 3.454089164733887e-05
# iteration 59, reconstruction error: 0.3219119906425476, decrease = 3.4332275390625e-05
# iteration 60, reconstruction error: 0.3218774199485779, decrease = 3.457069396972656e-05
# iteration 61, reconstruction error: 0.32184308767318726, decrease = 3.4332275390625e-05
# iteration 62, reconstruction error: 0.3218078911304474, decrease = 3.5196542739868164e-05
# iteration 63, reconstruction error: 0.3217737674713135, decrease = 3.412365913391113e-05
# iteration 64, reconstruction error: 0.3217385709285736, decrease = 3.5196542739868164e-05
# iteration 65, reconstruction error: 0.32170313596725464, decrease = 3.5434961318969727e-05
# iteration 66, reconstruction error: 0.32166749238967896, decrease = 3.5643577575683594e-05
# iteration 67, reconstruction error: 0.3216322660446167, decrease = 3.522634506225586e-05
# iteration 68, reconstruction error: 0.3215981423854828, decrease = 3.412365913391113e-05
# iteration 69, reconstruction error: 0.3215639889240265, decrease = 3.415346145629883e-05
# iteration 70, reconstruction error: 0.32153043150901794, decrease = 3.355741500854492e-05
# iteration 71, reconstruction error: 0.3214971125125885, decrease = 3.331899642944336e-05
# iteration 72, reconstruction error: 0.3214646577835083, decrease = 3.2454729080200195e-05
# iteration 73, reconstruction error: 0.32143259048461914, decrease = 3.2067298889160156e-05
# iteration 74, reconstruction error: 0.3214013874530792, decrease = 3.120303153991699e-05
# iteration 75, reconstruction error: 0.3213716745376587, decrease = 2.9712915420532227e-05
# iteration 76, reconstruction error: 0.3213423788547516, decrease = 2.9295682907104492e-05
# iteration 77, reconstruction error: 0.3213149607181549, decrease = 2.7418136596679688e-05
# iteration 78, reconstruction error: 0.3212875723838806, decrease = 2.7388334274291992e-05
# iteration 79, reconstruction error: 0.3212612569332123, decrease = 2.631545066833496e-05
# iteration 80, reconstruction error: 0.32123681902885437, decrease = 2.4437904357910156e-05
# iteration 81, reconstruction error: 0.321213036775589, decrease = 2.378225326538086e-05
# iteration 82, reconstruction error: 0.3211904764175415, decrease = 2.256035804748535e-05
# iteration 83, reconstruction error: 0.3211694657802582, decrease = 2.1010637283325195e-05
# iteration 84, reconstruction error: 0.32114991545677185, decrease = 1.9550323486328125e-05
# iteration 85, reconstruction error: 0.3211311995983124, decrease = 1.8715858459472656e-05
# iteration 86, reconstruction error: 0.3211148679256439, decrease = 1.633167266845703e-05
# iteration 87, reconstruction error: 0.32109975814819336, decrease = 1.5109777450561523e-05
# iteration 88, reconstruction error: 0.32108619809150696, decrease = 1.3560056686401367e-05
# iteration 89, reconstruction error: 0.321073442697525, decrease = 1.2755393981933594e-05
# iteration 90, reconstruction error: 0.3210623562335968, decrease = 1.1086463928222656e-05
# iteration 91, reconstruction error: 0.3210521638393402, decrease = 1.0192394256591797e-05
# iteration 92, reconstruction error: 0.32104259729385376, decrease = 9.566545486450195e-06
# iteration 93, reconstruction error: 0.32103389501571655, decrease = 8.702278137207031e-06
# iteration 94, reconstruction error: 0.3210262358188629, decrease = 7.659196853637695e-06
# iteration 95, reconstruction error: 0.3210189938545227, decrease = 7.241964340209961e-06
# iteration 96, reconstruction error: 0.32101261615753174, decrease = 6.377696990966797e-06
# iteration 97, reconstruction error: 0.3210068941116333, decrease = 5.7220458984375e-06
# iteration 98, reconstruction error: 0.3210011422634125, decrease = 5.751848220825195e-06
# iteration 99, reconstruction error: 0.3209960460662842, decrease = 5.0961971282958984e-06
# iteration 100, reconstruction error: 0.320991575717926, decrease = 4.470348358154297e-06
# iteration 101, reconstruction error: 0.320987343788147, decrease = 4.231929779052734e-06
# iteration 102, reconstruction error: 0.32098349928855896, decrease = 3.844499588012695e-06
# iteration 103, reconstruction error: 0.3209794759750366, decrease = 4.023313522338867e-06
# iteration 104, reconstruction error: 0.32097673416137695, decrease = 2.7418136596679688e-06
# iteration 105, reconstruction error: 0.32097330689430237, decrease = 3.427267074584961e-06
# iteration 106, reconstruction error: 0.3209701180458069, decrease = 3.1888484954833984e-06
# iteration 107, reconstruction error: 0.32096734642982483, decrease = 2.771615982055664e-06
# iteration 108, reconstruction error: 0.3209650218486786, decrease = 2.3245811462402344e-06
# iteration 109, reconstruction error: 0.32096269726753235, decrease = 2.3245811462402344e-06
# iteration 110, reconstruction error: 0.3209599256515503, decrease = 2.771615982055664e-06
# iteration 111, reconstruction error: 0.3209582269191742, decrease = 1.6987323760986328e-06
# iteration 112, reconstruction error: 0.32095566391944885, decrease = 2.562999725341797e-06
# iteration 113, reconstruction error: 0.32095441222190857, decrease = 1.2516975402832031e-06
# iteration 114, reconstruction error: 0.32095226645469666, decrease = 2.1457672119140625e-06
# iteration 115, reconstruction error: 0.320950984954834, decrease = 1.2814998626708984e-06
# iteration 116, reconstruction error: 0.32094883918762207, decrease = 2.1457672119140625e-06
# iteration 117, reconstruction error: 0.3209475874900818, decrease = 1.2516975402832031e-06
# iteration 118, reconstruction error: 0.3209460973739624, decrease = 1.4901161193847656e-06
# iteration 119, reconstruction error: 0.320944607257843, decrease = 1.4901161193847656e-06
# iteration 120, reconstruction error: 0.32094311714172363, decrease = 1.4901161193847656e-06
# iteration 121, reconstruction error: 0.32094207406044006, decrease = 1.043081283569336e-06
# iteration 122, reconstruction error: 0.3209407925605774, decrease = 1.2814998626708984e-06
# iteration 123, reconstruction error: 0.32093971967697144, decrease = 1.0728836059570312e-06
# iteration 124, reconstruction error: 0.3209386467933655, decrease = 1.0728836059570312e-06
# iteration 125, reconstruction error: 0.3209378123283386, decrease = 8.344650268554688e-07
# iteration 126, reconstruction error: 0.32093653082847595, decrease = 1.2814998626708984e-06
# iteration 127, reconstruction error: 0.3209356963634491, decrease = 8.344650268554688e-07
# iteration 128, reconstruction error: 0.32093483209609985, decrease = 8.642673492431641e-07
# iteration 129, reconstruction error: 0.320933997631073, decrease = 8.344650268554688e-07
# iteration 130, reconstruction error: 0.32093334197998047, decrease = 6.556510925292969e-07
# iteration 131, reconstruction error: 0.3209320902824402, decrease = 1.2516975402832031e-06
# iteration 132, reconstruction error: 0.32093122601509094, decrease = 8.642673492431641e-07
# iteration 133, reconstruction error: 0.3209305703639984, decrease = 6.556510925292969e-07
# iteration 134, reconstruction error: 0.32092952728271484, decrease = 1.043081283569336e-06
# iteration 135, reconstruction error: 0.3209289014339447, decrease = 6.258487701416016e-07
# iteration 136, reconstruction error: 0.32092803716659546, decrease = 8.642673492431641e-07
# iteration 137, reconstruction error: 0.3209271728992462, decrease = 8.642673492431641e-07
# iteration 138, reconstruction error: 0.3209265470504761, decrease = 6.258487701416016e-07
# iteration 139, reconstruction error: 0.3209257125854492, decrease = 8.344650268554688e-07
# iteration 140, reconstruction error: 0.3209248483181, decrease = 8.642673492431641e-07
# iteration 141, reconstruction error: 0.32092419266700745, decrease = 6.556510925292969e-07
# iteration 142, reconstruction error: 0.3209233582019806, decrease = 8.344650268554688e-07
# iteration 143, reconstruction error: 0.32092252373695374, decrease = 8.344650268554688e-07
# iteration 144, reconstruction error: 0.3209218680858612, decrease = 6.556510925292969e-07
# iteration 145, reconstruction error: 0.32092124223709106, decrease = 6.258487701416016e-07
# iteration 146, reconstruction error: 0.3209201693534851, decrease = 1.0728836059570312e-06
# iteration 147, reconstruction error: 0.3209195137023926, decrease = 6.556510925292969e-07
# iteration 148, reconstruction error: 0.32091888785362244, decrease = 6.258487701416016e-07
# iteration 149, reconstruction error: 0.3209182322025299, decrease = 6.556510925292969e-07
# iteration 150, reconstruction error: 0.32091718912124634, decrease = 1.043081283569336e-06
# iteration 151, reconstruction error: 0.3209163248538971, decrease = 8.642673492431641e-07
# iteration 152, reconstruction error: 0.32091569900512695, decrease = 6.258487701416016e-07
# iteration 153, reconstruction error: 0.3209148645401001, decrease = 8.344650268554688e-07
# iteration 154, reconstruction error: 0.32091379165649414, decrease = 1.0728836059570312e-06
# iteration 155, reconstruction error: 0.3209133744239807, decrease = 4.172325134277344e-07
# iteration 156, reconstruction error: 0.32091230154037476, decrease = 1.0728836059570312e-06
# iteration 157, reconstruction error: 0.3209116756916046, decrease = 6.258487701416016e-07
# iteration 158, reconstruction error: 0.32091018557548523, decrease = 1.4901161193847656e-06
# iteration 159, reconstruction error: 0.3209097683429718, decrease = 4.172325134277344e-07
# iteration 160, reconstruction error: 0.32090866565704346, decrease = 1.1026859283447266e-06
# iteration 161, reconstruction error: 0.320907860994339, decrease = 8.046627044677734e-07
# iteration 162, reconstruction error: 0.32090675830841064, decrease = 1.1026859283447266e-06
# iteration 163, reconstruction error: 0.3209059238433838, decrease = 8.344650268554688e-07
# iteration 164, reconstruction error: 0.32090529799461365, decrease = 6.258487701416016e-07
# iteration 165, reconstruction error: 0.3209042251110077, decrease = 1.0728836059570312e-06
# iteration 166, reconstruction error: 0.32090315222740173, decrease = 1.0728836059570312e-06
# iteration 167, reconstruction error: 0.3209022879600525, decrease = 8.642673492431641e-07
# iteration 168, reconstruction error: 0.3209012448787689, decrease = 1.043081283569336e-06
# iteration 169, reconstruction error: 0.3209003806114197, decrease = 8.642673492431641e-07
# iteration 170, reconstruction error: 0.32089951634407043, decrease = 8.642673492431641e-07
# iteration 171, reconstruction error: 0.32089847326278687, decrease = 1.043081283569336e-06
# iteration 172, reconstruction error: 0.3208976089954376, decrease = 8.642673492431641e-07
# iteration 173, reconstruction error: 0.32089656591415405, decrease = 1.043081283569336e-06
# iteration 174, reconstruction error: 0.3208954930305481, decrease = 1.0728836059570312e-06
# iteration 175, reconstruction error: 0.32089442014694214, decrease = 1.0728836059570312e-06
# iteration 176, reconstruction error: 0.3208935856819153, decrease = 8.344650268554688e-07
# iteration 177, reconstruction error: 0.3208923041820526, decrease = 1.2814998626708984e-06
# iteration 178, reconstruction error: 0.32089167833328247, decrease = 6.258487701416016e-07
# iteration 179, reconstruction error: 0.3208903968334198, decrease = 1.2814998626708984e-06
# iteration 180, reconstruction error: 0.32088911533355713, decrease = 1.2814998626708984e-06
# iteration 181, reconstruction error: 0.32088804244995117, decrease = 1.0728836059570312e-06
# iteration 182, reconstruction error: 0.3208869993686676, decrease = 1.043081283569336e-06
# iteration 183, reconstruction error: 0.32088592648506165, decrease = 1.0728836059570312e-06
# iteration 184, reconstruction error: 0.3208850920200348, decrease = 8.344650268554688e-07
# iteration 185, reconstruction error: 0.32088401913642883, decrease = 1.0728836059570312e-06
# iteration 186, reconstruction error: 0.32088252902030945, decrease = 1.4901161193847656e-06
# iteration 187, reconstruction error: 0.320882111787796, decrease = 4.172325134277344e-07
# iteration 188, reconstruction error: 0.32088103890419006, decrease = 1.0728836059570312e-06
# iteration 189, reconstruction error: 0.3208795487880707, decrease = 1.4901161193847656e-06
# iteration 190, reconstruction error: 0.32087892293930054, decrease = 6.258487701416016e-07
# iteration 191, reconstruction error: 0.32087743282318115, decrease = 1.4901161193847656e-06
# iteration 192, reconstruction error: 0.3208765685558319, decrease = 8.642673492431641e-07
# iteration 193, reconstruction error: 0.32087528705596924, decrease = 1.2814998626708984e-06
# iteration 194, reconstruction error: 0.3208744525909424, decrease = 8.344650268554688e-07
# iteration 195, reconstruction error: 0.32087358832359314, decrease = 8.642673492431641e-07
# iteration 196, reconstruction error: 0.32087254524230957, decrease = 1.043081283569336e-06
# iteration 197, reconstruction error: 0.3208712637424469, decrease = 1.2814998626708984e-06
# iteration 198, reconstruction error: 0.32087063789367676, decrease = 6.258487701416016e-07
# iteration 199, reconstruction error: 0.3208695650100708, decrease = 1.0728836059570312e-06
# iteration 200, reconstruction error: 0.32086849212646484, decrease = 1.0728836059570312e-06
# iteration 201, reconstruction error: 0.3208674192428589, decrease = 1.0728836059570312e-06
# iteration 202, reconstruction error: 0.3208663761615753, decrease = 1.043081283569336e-06
# iteration 203, reconstruction error: 0.32086530327796936, decrease = 1.0728836059570312e-06
# iteration 204, reconstruction error: 0.3208644390106201, decrease = 8.642673492431641e-07
# iteration 205, reconstruction error: 0.32086381316185, decrease = 6.258487701416016e-07
# iteration 206, reconstruction error: 0.3208625316619873, decrease = 1.2814998626708984e-06
# iteration 207, reconstruction error: 0.3208621144294739, decrease = 4.172325134277344e-07
# iteration 208, reconstruction error: 0.3208608329296112, decrease = 1.2814998626708984e-06
# iteration 209, reconstruction error: 0.32085999846458435, decrease = 8.344650268554688e-07
# iteration 210, reconstruction error: 0.3208591341972351, decrease = 8.642673492431641e-07
# iteration 211, reconstruction error: 0.32085829973220825, decrease = 8.344650268554688e-07
# iteration 212, reconstruction error: 0.3208571970462799, decrease = 1.1026859283447266e-06
# iteration 213, reconstruction error: 0.3208570182323456, decrease = 1.7881393432617188e-07
# iteration 214, reconstruction error: 0.3208559453487396, decrease = 1.0728836059570312e-06
# iteration 215, reconstruction error: 0.3208552896976471, decrease = 6.556510925292969e-07
# iteration 216, reconstruction error: 0.32085466384887695, decrease = 6.258487701416016e-07
# iteration 217, reconstruction error: 0.3208540081977844, decrease = 6.556510925292969e-07
# iteration 218, reconstruction error: 0.3208536207675934, decrease = 3.8743019104003906e-07
# iteration 219, reconstruction error: 0.32085275650024414, decrease = 8.642673492431641e-07
# iteration 220, reconstruction error: 0.3208523392677307, decrease = 4.172325134277344e-07
# iteration 221, reconstruction error: 0.3208516836166382, decrease = 6.556510925292969e-07
# iteration 222, reconstruction error: 0.32085105776786804, decrease = 6.258487701416016e-07
# iteration 223, reconstruction error: 0.32085081934928894, decrease = 2.384185791015625e-07
# iteration 224, reconstruction error: 0.3208506405353546, decrease = 1.7881393432617188e-07
# iteration 225, reconstruction error: 0.32084956765174866, decrease = 1.0728836059570312e-06
# iteration 226, reconstruction error: 0.32084956765174866, decrease = 0.0
# PARAFAC converged after 226 iterations

# %% [markdown]
# Rearrange the factors.\
# You can undo the concatenation that was done during `.rearrange_data`

# %%
tca.rearrange_factors(
    undo_concat_complexDim=False,
    undo_concat_dictElements=False,
)

# %% [markdown]
# Save the `TCA` object in 'analysis_files' project directory.

# %%
tca.save_config(path_config=path_config, overwrite=True, verbose=1)
tca.save_run_info(path_config=path_config, overwrite=True, verbose=1)
tca.save_run_data(path_config=path_config, overwrite=True, use_compression=False, verbose=1)
# Out:
# FR WARNING: path_run_data file is expected to be named 'TCA.h5' if it is part of a project. Please make sure this is correct.

# %% [markdown]
# Clear some memory if needed. Useful if you ran the fit on a GPU. Optional.

# %%
tca._cleanup()

# %%
tca.plot_factors(
    figure_saver=None,
    show_figures=True,
)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Load the `TCA` data as a dictionary

# %%
tca_data = fr.h5_handling.simple_load(str(Path(directory_project) / 'analysis_files' / 'TCA.h5'), return_dict=False)

# %% [markdown]
# # Demo playback

# %% [markdown]
# Playback a video with points overlayed.\
# Make sure you have a `BufferedVideoReader` object called `videos` made of your videos

# %%
idx_video_to_use = 0
idx_frames_to_use = np.arange(8000,9000)

videos.method_getitem = 'by_video'

frame_visualizer = fr.visualization.FrameVisualizer(
    display=True,
    error_checking=True,
    verbose=2,
#     path_save=str(Path(directory_project) / 'visualizations' / 'point_tracking_demo.avi'),
    path_save=None,
    frame_height_width=videos.frame_height_width,
    frame_rate=data.frame_rate,
    point_sizes=3,
    points_colors=(0,255,255),
#     points_colors=[(cmap((factor_magnitudes / factor_magnitudes.max(0)))*255)[:,:,:3].astype(int).transpose(1,0,2)[0]],
    alpha=0.6,
)

fr.visualization.play_video_with_points(
    bufferedVideoReader=videos[idx_video_to_use],
    frameVisualizer=frame_visualizer,
    points=list(pt_data['points_tracked'].values())[0],
    idx_frames=idx_frames_to_use,
)
# Out:
# <class 'face_rhythm.helpers.BufferedVideoReader'>
